# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

btc = pd.read_csv('data/model/btc_model_price.csv')
btc
# Out:
#      Tomorrow        Date    Price  Change %  Volume_pct_change  \
# 0           0  2024-06-29  60973.4    0.0094                NaN
# 1           1  2024-06-28  60403.3   -0.0208         121.950301
# 2           0  2024-06-27  61685.3    0.0137         -17.234945
# 3           1  2024-06-26  60849.4   -0.0155          12.625538
# 4           0  2024-06-25  61809.4    0.0252          40.636943
# ..        ...         ...      ...       ...                ...
# 176         0  2024-01-05  44156.9    0.0000         180.585326
# 177         0  2024-01-04  44157.0    0.0308          -0.029382
# 178         1  2024-01-03  42836.1   -0.0469          72.887583
# 179         0  2024-01-02  44943.7    0.0172         -16.838079
# 180         1  2024-01-01  44183.4    0.0452         -62.898610
#
#      Gold_pct_change  Gold_Volume_pct_change  SNP_pct_change  VIX_pct_change  \
# 0                NaN                     NaN             NaN             NaN
# 1             0.0013                     NaN         -0.0041          0.0163
# 2             0.0155                0.000000          0.0009         -0.0247
# 3            -0.0075              -99.294017          0.0016         -0.0226
# 4            -0.0060               27.272727          0.0039         -0.0368
# ..               ...                     ...             ...             ...
# 176          -0.0001                0.000000          0.0018         -0.0552
# 177           0.0035              -39.323644         -0.0034          0.0064
# 178          -0.0148               70.182712         -0.0080          0.0636
# 179           0.0008              -28.924576         -0.0057          0.0602
# 180          -0.0056              -32.901752         -0.0028         -0.0016
#
#      VIX_pct_change_pct_change  ...  TVL_pct_change  \
# 0                          NaN  ...             NaN
# 1                          NaN  ...        2.094633
# 2                  -251.533742  ...       -0.945106
# 3                    -8.502024  ...        1.932857
# 4                    62.831858  ...       -3.250849
# ..                         ...  ...             ...
# 176                   0.000000  ...        0.528495
# 177                -111.594203  ...       -3.015292
# 178                 893.750000  ...        5.225437
# 179                  -5.345912  ...       -2.875209
# 180                -102.657807  ...       -3.312747
#
#      weighted_sentiment_pct_change  MA_td  3MA_td  %K_td  %D_td  RSI_td  \
# 0                              NaN      0       0      0      0       0
# 1                      -200.610227      0       0      0      0       0
# 2                        38.968818      0       0      0      0       0
# 3                       -34.363899      0       0      0      0       0
# 4                        81.602022      0       0      0      0       0
# ..                             ...    ...     ...    ...    ...     ...
# 176                       0.000000      0       1      1      0       0
# 177                       0.000000      0       1      0      1       0
# 178                    -171.188530      0       1      0      0       0
# 179                       0.000000      0       1      1      1       0
# 180                       0.000000      0       1      0      1       0
#
#      Momentum_td  MACD_td  CCI_td
# 0              0        0       0
# 1              0        0       0
# 2              0        1       0
# 3              0        0       0
# 4              0        1       0
# ..           ...      ...     ...
# 176            1        0       0
# 177            1        0       0
# 178            0        0       0
# 179            1        1       0
# 180            0        1       0
#
# [181 rows x 22 columns]

# %% [markdown]
# #### Make a basic correlogram

# %%
btc = btc[['Tomorrow', 'Price', 'Change %', 'Volume_pct_change',
       'Gold_pct_change', 'Gold_Volume_pct_change', 'SNP_pct_change',
       'VIX_pct_change', 'VIX_pct_change_pct_change',
       'Wikipedia_Views_pct_change', 'Google_Trends_pct_change',
       'TVL_pct_change', 'weighted_sentiment_pct_change', 'MA_td', '3MA_td',
       '%K_td', '%D_td', 'RSI_td', 'Momentum_td', 'MACD_td', 'CCI_td']]


corr = btc.corr()

# Create the correlogram
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1, square=True, linewidths=.5)
plt.title('Correlogram')
plt.show()
